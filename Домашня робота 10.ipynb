# %% [markdown]
# ___
# <a href='https://mainacademy.ua/' style="background-color:powderblue;">
#     <img src="https://mainacademy.ua/wp-content/themes/mainacademy/assets/images/logo.svg"
#          alt = 'Хмм, щось з інтернетом'
#          style="background-color:rgba(0, 0, 100, 1);" />
# </a>
#
# ___
#
# # Module 6: Basics of data visualization

# %% [markdown]
# # Lab work 6

# %% [markdown]
# #### Мета:
#
# * навчитися візуалізовувати дані в Python

# %% [markdown]
# ##### Імпортуємо необхідні бібліотеки.

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Завдання 1

# %% [markdown]
# Дано

# %%
np.random.seed(0)

df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30)})
df.head()
# Out:
#     a   b   c
# 0  44  47  17
# 1  47  64  79
# 2  64  82   4
# 3  67  99  42
# 4  67  88  58

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
#  - перші 3 графіки візуалізувати, викорстовуючи значення із df
#  - останній це пряма пропорційність

# %%
fig, ax = plt.subplots(2, 2, figsize=(20,10))
ax[0][0].plot(df.a, '-')
ax[0][1].plot(df.b, '-')
ax[1][0].plot(df.c,  '-')
ax[1][1].plot(df.a, df.a, '-')
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку

# %%
fig, axes = plt.subplots(figsize=(20,9))
plt.plot(df.a, '-')
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`

# %%
fig, ax = plt.subplots(2, figsize=(20,10))
ax[0].plot(df.a, '-')
ax[1].plot(df.b, '-')
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`

# %%
fig = plt.figure(figsize=(10,5), dpi=100)

plt.plot(df.a, 'y', df.b)

plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`
# - задайте стиль 'darkgrid' за допомогою команди `sns.set_style`

# %%
sns.set_style("darkgrid")

fig = plt.figure(figsize=(10,5), dpi=100)
plt.plot(df.a, 'y', df.b)
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - для колонки `a` використайте червоний колір та лінію формату `-.`
#
# - для колонки `b` використайте помаранчевий колір та товщину `10`
#
# - для колонки `c` використайте жовтий колір та товщину `1` і маркер `o`

# %%
sns.set_style("darkgrid")

fig = plt.figure(figsize=(10,5), dpi=100)
plt.plot(df.a, 'r-', df.b, 'orange', df.c, 'y-o')
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - і не забудьте про легенду :)

# %%
sns.set_style("darkgrid")
fig, ax = plt.subplots(3, figsize=(20,7))
ax[0].plot(df.a, '-', label="label a")
ax[1].plot(df.b, '-', label="label b")
ax[2].plot(df.c, '-', label="label c")
ax[0].legend(loc=4) 
ax[1].legend(loc=6) 
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використайте томатний колір та відстань між стовбцями 0.5

# %%
sns.set_style("darkgrid")
fig = plt.figure(figsize=(20,7))
arr = sns.barplot(x = df.a, y = df.b, data = df,
            color='salmon', ci=None, label="a"
            )
arr.legend(loc=1) 
plt.show()

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - добавте всі підписи та правильний маркер

# %%
sns.set_style("darkgrid")

fig, axes = plt.subplots(figsize=(20,9))
plt.plot(df.a, '-')
plt.xlabel('This is the X Axis', size=20)
plt.ylabel('This is the Y Axis')
plt.minorticks_on()
# включаем основную сетку
plt.grid(which='major')
# включаем дополнительную сетку
plt.grid(which='minor', linestyle=':')

plt.title('This is the Title')
plt.show()

# %% [markdown]
# ---
#
# ## Завдання 2

# %% [markdown]
# Дано

# %%
dfl = pd.read_excel('FOR_HW_10.xlsx')
dfl.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
#
#         Ship Mode Customer Segment  \
# 0     Express Air        Corporate
# 1  Delivery Truck      Home Office
# 2     Regular Air      Home Office
#
#                                         Product Name  Product Base Margin  \
# 0     SANFORD Liquid Accent™ Tank-Style Highlighters                 0.54
# 1     Global Troy™ Executive Leather Low-Back Tilter                 0.60
# 2  DAX Two-Tone Rosewood/Black Document Frame, De...                 0.45
#
#      ...    Region State or Province         City Postal Code  Order Date  \
# 0    ...      West        Washington    Anacortes       98221  2015-01-07
# ...

# %% [markdown]
# Використовуючи дані з excel файлу, створіть графіки відповідно до шаблону нижче. \
# Карту та таблицю - **не** обов'язково.
#
# > Використовуйте будь-яку зручну для вас бібліотеку для візуалізації.
#
# ![image.png](attachment:image.png)

# %%
df_1 = dfl.groupby(['Ship Mode'])['Profit'].mean()
plt.bar(df_1.index, df_1, color='teal')
plt.title('Average profit')
# Out:
# Text(0.5,1,'Average profit')

# %%
df_2 = dfl.groupby(['State or Province'])['Sales'].mean()
ax = df_2.plot(kind='barh', figsize=(8,8))
ax.set_xlabel('Sales')
plt.title('Average profit by of State')
# Out:
# Text(0.5,1,'Average profit by of State')

# %%
dfl.plot('Ship Date', 'Profit',figsize=(12, 3), color='teal')

# %%
# make data
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
dfl.add_trace(go.Pie(values=sum_counts, labels=sum_counts.index, pull=pull, hole=0.9))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-cc2d0da96c2a> in <module>()
# ----> 1 dfl.add_trace(go.Pie(values=sum_counts, labels=sum_counts.index, pull=pull, hole=0.9))
#       2 fig.show()
#
# C:\Users\dn120584gan2\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'add_trace'
