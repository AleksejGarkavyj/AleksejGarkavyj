# %% [markdown]
# ___
# <a href='https://mainacademy.ua/' style="background-color:powderblue;">
#     <img src="https://mainacademy.ua/wp-content/themes/mainacademy/assets/images/logo.svg"
#          alt = 'Хмм, щось з інтернетом'
#          style="background-color:rgba(0, 0, 100, 1);" />
# </a>
#
# ___
#
# # Module 4: Work with data professionally!

# %% [markdown]
# ## Домашня робота 7

# %% [markdown]
# ### Завдання 1

# %% [markdown]
# Потрібно проаналізувати всі товари на сайті:
# https://smallpacking.agrosem.ua/

# %% [markdown]
# Задача може включати такі кроки:
# - підключіться до головної сторінки магазину https://smallpacking.agrosem.ua/
# - зберіть інформацію про наявні розділи товарів (внизу є посилання під заголовком "НАША ПРОДУКЦІЯ")
# - для кожного розділу зберіть інформацію про усі товари (на всіх сторінках):
#  - код товару (щось типу "id" чи "data-id")
#  - назва товару
#  - розділ (добрива, насіння)
#  - ціна
#  - вага
#
# За бажанням можете зібрати ще якусь інформацію про товари. Наприклад, призначення і т.п.
# Якщо якоїсь інформації немає, то записати порожнє поле.
#
# Зібрані дані збережіть у зручному (на вашу думку) форматі (json, список, словник, база даних SQLite).

# %% [markdown]
# **ВАЖЛИВО**
# Для переключення між сторінками товарів потрібно робити запити в одній сесії.
# [Деталі тут.](https://requests.readthedocs.io/en/latest/user/advanced/#session-objects)
# ```python
# import requests
#
# s = requests.Session()
# r = s.get('https://smallpacking.agrosem.ua/')
# ```

# %% [markdown]
# **Зауваження.**
# За бажання чи необхідності сайт можна змінити.
# Тобто головна задача завдання - збір даних з певного сайту. А якого саме - не так важливо.

# %%
import requests
from bs4 import BeautifulSoup

list = {}
sl = []

url = 'https://privatbank.ua/'
dop_products = soup.find_all('div', class_='column-menu g-c1') 
for dop_product in dop_products:
    c_list = dop_product.find_all('a')
    name = c_list[0].text
   # print(f'Назва: {name} >> {link}')
    link = 'https://privatbank.ua'+ c_list[0].get('href').replace('https://privatbank.ua','')
    href = c_list[0].get('href').replace('https://privatbank.ua','').replace('/','_')
    r = requests.get(link)
    soup_dop = BeautifulSoup(r.text, 'lxml')
    c1_list = soup_dop.find_all('div', class_="wr_inner")  
    for c_product in c1_list:
        sl = c_product.text.split()
    list[href] = {'name': name,
                    'link': link,
                    'sl': sl}

# %%
from pprint import pprint
pprint(list)
# Out:
# {'_apps_moivkladi': {'link': 'https://privatbank.ua/apps/moivkladi',
#                      'name': 'Мобільний додаток «Мої вклади»',
#                      'sl': ['Олександр',
#                             'Онікієнко,',
#                             'відгук',
#                             'на',
#                             'Google',
#                             'Play',
#                             'Добре',
#                             'розширено',
#                             'функціонал.',
#                             'Тепер',
#                             'став',
#                             'додаток',
#                             'не',
#                             'ознайомчим,',
#                             'а',
#                             'робочим.',
#                             'Тримати',
#                             'так',
#                             'і',
#                             'далі.']},
#  '_cpa_applepay': {'link': 'https://privatbank.ua/cpa/applepay',
#                    'name': 'Apple Pay',
#                    'sl': ['Як', 'налаштувати', 'Apple', 'Pay?']},
#  '_deposit-rates': {'link': 'https://privatbank.ua/deposit-rates',
#                     'name': 'Тарифи за вкладами',
#                     'sl': ['Послуга',
#                            'Тариф',
#                            'Зарахування',
#                            'коштів',
#                            'з',
#                            'депозитного',
#                            'вкладу',
#                            'на',
#                            'Картку',
#                            'для',
#                            'виплат',
#                            'Не',
#                            'тарифікується',
#                            'Оформлення',
#                            'або',
#                            'зміна',
#                            'заповідального',
#                            'розпорядження',
#                            'Не',
#                            'тарифікується',
#                            'Оформлення',
#                            'довіреності',
#                            'Не',
#                            'тарифікується',
#                            'Переказ',
#                            'коштів',
#                            'з',
#                            'картки',
#                            '«Універсальна»,',
#                            'елітної',
#                            'картки,',
#                            'поточного',
#                            'рахунку',
#                            'фізичної',
#                            'особи,',
#                            'віртуального',
#                            'рахунку,',
#                            'Інтернет-картки',
#                            'та',
#                            'вкладу',
#                            '«До',
#                            'запитання»',
#                            'на',
#                            '«Приват-вклад»',
#                            '1%',
#                            'від',
#                            'суми',
#                            'Поповнення',
#                            '«Приват-вкладу»',
#                            'або',
#                            '«Слава',
#                            'Героям»',
#                            'за',
#                            'довіреністю',
#                            '(банківською',
#                            'або',
#                            'нотаріальною)',
#                            'готівкою',
#                            'або',
#                            'безготівковим',
#                            'платежем',
#                            '(тариф',
#                            'стягується',
#                            'з',
#                            'одержувача)',
#                            '0,5%',
#                            'від',
#                            'суми',
#                            'поповнення',
#                            'Поповнення',
#                            'послуги',
#                            '«Скарбничка»',
#                            'з',
#                            'картки',
#                            '«Універсальна»,',
#                            '«Універсальна',
#                            'Gold»,',
#                            'картки',
#                            'Юніора,',
#                            'та',
#                            'Елітних',
#                            'карток',
#                            '1%',
#                            'від',
#                            'суми,',
#                            'окрім',
#                            'переказу',
#                            'коштів',
#                            'за',
#                            'умовою',
#                            'накопичення',
#                            '«Округлення',
#                            'витрати»,',
#                            '«Округлення',
#                            'залишку',
#                            'на',
#                            'картці',
#                            'наприкінці',
#                            'дня»',
#                            'Завантажити',
#                            'pdf']},
#  '_depozit': {'link': 'https://privatbank.ua/depozit',
#               'name': 'Процентні ставки за вкладами',
#               'sl': ['Додатково',
#                      'захищає',
#                      'ваші',
#                      'гривневі',
#                      'заощадження',
#                      'у',
#                      'разі',
#                      'подорожчання',
#                      'долара',
#                      'Ми',
#                      'підтримали',
#                      'ініціативу',
#                      'НБУ',
#                      'та',
#                      'запустили',
#                      'новий',
#                      'валютний',
#                      'вклад',
#                      '«Капітал».',
#                      'Він',
#                      'додатково',
#                      'захистить',
#                      'ваші',
#                      'гривневі',
#                      'заощадження',
#                      'в',
#                      'разі',
#                      'подорожчання',
#                      'долара.',
#                      'Про',
#                      'фішки',
#                      'вкладу',
#                      'Для',
#                      'оформлення',
#                      'вкладу',
#                      'можна',
#                      'онлайн',
#                      'купувати',
#                      'долари',
#                      'без',
#                      'обмежень',
#                      'за',
#                      'сумою.',
#                      'Купівля',
#                      'валюти',
#                      'здійснюється',
#                      'з',
#                      'гривневих',
#                      'карток',
#                      'за',
#                      'курсом',
#                      'НБУ',
#                      '(вигідний',
#                      'курс,',
#                      'і',
#                      'до',
#                      'того',
#                      'ж',
#                      'без',
#                      'комісій).',
#                      'Як',
#                      'працює',
#                      'вклад',
#                      '«Капітал»',
#                      'У',
#                      'Приват24',
#                      'перейдіть',
#                      'у',
#                      'меню',
#                      '«Заощадження»',
#                      '→',
#                      '«Відкрити',
#                      'вклад»',
#                      'і',
#                      'виберіть',
#                      'вклад',
#                      '«Капітал».',
#                      'Виберіть',
#                      'гривневу',
#                      'картку,',
#                      'з',
#                      'якої',
#                      'купити',
#                      'долари.',
#                      'Після',
#                      'закінчення',
#                      'вкладу',
#                      'вся',
#                      'сума',
#                      'разом',
#                      'із',
#                      '%',
#                      'автоматично',
#                      'повернеться',
#                      'на',
#                      'гривневу',
#                      'картку,',
#                      'з',
#                      'якої',
#                      'було',
#                      'відкрито',
#                      'вклад,',
#                      'за',
#                      'поточним',
#                      'курсом',
#                      'НБУ.',
#                      'Ми',
#                      'віримо,',
#                      'що',
#                      'завдяки',
#                      'цьому',
#                      'вкладу',
#                      'нам',
#                      'вдасться',
#                      'зробити',
#                      'життя',
#                      'хоч',
#                      'трохи',
#                      'спокійнішим.',
#                      'ОФОРМИТИ',
#                      'Показати',
#                      'більше']},
#  '_handbook_oholoshennya-pro-zaluchennya-notariusiv': {'link': 'https://privatbank.ua/handbook/oholoshennya-pro-zaluchennya-notariusiv',
#                                                        'name': 'Оголошення про '
#                                                                'залучення '
#                                                                'нотаріусів',
#                                                        'sl': []},
#  '_kak-otpravit-dengi-za-granicu': {'link': 'https://privatbank.ua/kak-otpravit-dengi-za-granicu',
#                                     'name': 'Як надіслати кошти за кордон',
#                                     'sl': ['Куди',
#                                            'звертатися,',
#                                            'якщо',
#                                            'виникли',
#                                            'запитання',
#                                            'щодо',
#                                            'TransferWise,',
#                                            'TransferGo,',
#                                            'SWIFT-переказів?',
#                                            'Тел.:',
#                                            '+38',
#                                            '(073)',
#                                            '900',
#                                            '00',
#                                            '04',
#                                            '(9:00–21:00).',
#                                            'E-mail:',
#                                            'swift@privatbank.ua;',
#                                            'Тел.:',
#                                            '+38',
#                                            '(073)',
#                                            '900',
#                                            '00',
#                                            '02',
#                                            '–',
#                                            'Консьєрж-сервіс',
#                                            'для',
#                                            'VIP-клієнтів',
#                                            '(цілодобово).']},
#  '_kak-poluchit-dengi-iz-za-granicu': {'link': 'https://privatbank.ua/kak-poluchit-dengi-iz-za-granicu',
#                                        'name': 'Як отримати кошти з-за кордону',
#                                        'sl': ['Показати',
#                                               'всi',
#                                               'питання',
#                                               '+3']},
#  '_kredity': {'link': 'https://privatbank.ua/kredity',
#               'name': 'Який кредит вибрати?',
#               'sl': ['Ви',
#                      'можете',
#                      'придбати',
#                      'в',
#                      'кредит',
#                      'житло',
#                      'та',
#                      'комерційну',
#                      'нерухомість',
#                      'на',
#                      'вигідних',
#                      'умовах.',
#                      'Великий',
#                      'вибір',
#                      'заставної',
#                      'нерухомості',
#                      'за',
#                      'доступними',
#                      'цінами',
#                      'в',
#                      'усіх',
#                      'регіонах',
#                      'України.',
#                      'Знижена',
#                      'кредитна',
#                      'ставка,',
#                      'оперативне',
#                      'оформлення',
#                      'та',
#                      'безпека',
#                      'угоди.',
#                      'Дізнатися',
#                      'більше']},
#  '_kredity_avto-v-kredit': {'link': 'https://privatbank.ua/kredity/avto-v-kredit',
#                             'name': 'Авто з пробігом',
#                             'sl': ['Чи',
#                                    'можливе',
#                                    'дострокове',
#                                    'розірвання',
#                                    'договору',
#                                    'про',
#                                    'надання',
#                                    'банківської',
#                                    'послуги?',
#                                    'Як',
#                                    'розірвати',
#                                    'такий',
#                                    'договір?',
#                                    'Відповідно',
#                                    'до',
#                                    'ст.',
#                                    '651',
#                                    'Цивільного',
#                                    'кодексу',
#                                    'України',
#                                    'можливо',
#                                    'здійснити',
#                                    'одностороннє',
#                                    'розірвання',
#                                    'договору',
#                                    'з',
#                                    'надсиланням',
#                                    'позичальнику',
#                                    'відповідного',
#                                    'повідомлення.',
#                                    'У',
#                                    'зазначену',
#                                    'в',
#                                    'повідомленні',
#                                    'дату',
#                                    'договір',
#                                    'вважається',
#                                    'розірваним.',
#                                    'Одностороннє',
#                                    'розірвання',
#                                    'договору',
#                                    'не',
#                                    'звільняє',
#                                    'лізингоодержувача',
#                                    'від',
#                                    'відповідальності',
#                                    'за',
#                                    'порушення',
#                                    'зобов’язань',
#                                    'за',
#                                    'цим',
#                                    'договором.',
#                                    'Згідно',
#                                    'з',
#                                    'договором',
#                                    'фінансового',
#                                    'лізингу',
#                                    '(пп.',
#                                    '8.2.5).']},
#  '_notariat_': {'link': 'https://privatbank.ua/notariat/',
#                 'name': 'Нотаріальні платежі',
#                 'sl': ['Як',
#                        'заблокувати',
#                        'або',
#                        'розблокувати',
#                        'Картку',
#                        'для',
#                        'виплат?',
#                        'Заблокувати',
#                        'або',
#                        'розблокувати',
#                        'свою',
#                        'Картку',
#                        'для',
#                        'виплат',
#                        'Ви',
#                        'можете:',
#                        'У',
#                        'Приват24',
#                        '–',
#                        'меню',
#                        '«Мої',
#                        'рахунки»/«Блокування/Розблокування',
#                        'карток».',
#                        'Через',
#                        'мобільний',
#                        'додаток',
#                        '«SMS-банкінг»',
#                        'або',
#                        'за',
#                        'командою',
#                        'SMS-банкингу.',
#                        'Зателефонувавши',
#                        'в',
#                        'клієнтську',
#                        'підтримку',
#                        '3700',
#                        '(з',
#                        'мобільних',
#                        'телефонів',
#                        '–',
#                        'безкоштовно).',
#                        'Через',
#                        'банкомат',
#                        'ПриватБанку',
#                        'в',
#                        'меню',
#                        '«Операції',
#                        'з',
#                        'карткою»/«Додаткові',
#                        'послуги»/«Заблокувати/Розблокувати',
#                        'картку».',
#                        'У',
#                        'будь-якому',
#                        'відділенні',
#                        'ПриватБанку.']},
#  '_perekaz-z-privat24': {'link': 'https://privatbank.ua/perekaz-z-privat24',
#                          'name': 'Приват24: як легко отримувати та надсилати '
#                                  'гроші за кордон',
#                          'sl': ['Через',
#                                 'Приват24',
#                                 'ви',
#                                 'можете:',
#                                 'надіслати',
#                                 'переказ',
#                                 'на',
#                                 'картку',
#                                 'будь-якого',
#                                 'банку',
#                                 'світу;',
#                                 'отримати',
#                                 'переказ',
#                                 'з',
#                                 'картки',
#                                 'будь-якого',
#                                 'банку',
#                                 'світу.',
#                                 'Якщо',
#                                 'картка',
#                                 'відправника',
#                                 'платіжної',
#                                 'системи',
#                                 'Visa',
#                                 'або',
#                                 'Mastercard,',
#                                 'то',
#                                 'переказ',
#                                 'з',
#                                 'іноземної',
#                                 'картки',
#                                 'на',
#                                 'картку',
#                                 'ПриватБанку',
#                                 'можливий',
#                                 'з',
#                                 'усіх',
#                                 'країн,',
#                                 'окрім',
#                                 'Білорусі,',
#                                 'Ірану,',
#                                 'Іраку,',
#                                 'Росії,',
#                                 'Сирії,',
#                                 'Куби,',
#                                 'Північної',
#                                 'Кореї,',
#                                 'Судану,',
#                                 'Південного',
#                                 'Судану,',
#                                 'Нікарагуа.',
#                                 'Переказ',
#                                 'через',
#                                 'Приват24',
#                                 'можна',
#                                 'надіслати',
#                                 'в',
#                                 'будь-яку',
#                                 'країну',
#                                 'світу,',
#                                 'окрім:',
#                                 'Білорусі,',
#                                 'Ірану,',
#                                 'Іраку,',
#                                 'Росії,',
#                                 'Сирії,',
#                                 'Куби,',
#                                 'Північної',
#                                 'Кореї,',
#                                 'Судану,',
#                                 'Південного',
#                                 'Судану,',
#                                 'Нікарагуа',
#                                 '(країни',
#                                 'перебувають',
#                                 'під',
#                                 'санкціями);',
#                                 'США,',
#                                 'Японії,',
#                                 'Індії',
#                                 '(не',
#                                 'дозволено',
#                                 'внутрішнім',
#                                 'законодавством',
#                                 'цих',
#                                 'країн).',
#                                 'Щоб',
#                                 'надіслати',
#                                 'або',
#                                 'отримати',
#                                 'міжнародний',
#                                 'переказ,',
#                                 'зайдіть',
#                                 'в',
#                                 'Інтернет-банк',
#                                 'Приват24',
#                                 'та',
#                                 'виберіть',
#                                 'меню',
#                                 '«Перекази»',
#                                 '→',
#                                 '«На',
#                                 'будь-яку',
#                                 'картку».',
#                                 'Заповніть',
#                                 'дані',
#                                 'картки',
#                                 'відправника,',
#                                 'дані',
#                                 'картки',
#                                 'одержувача,',
#                                 'суму,',
#                                 'валюту',
#                                 'й',
#                                 'натисніть',
#                                 'кнопку',
#                                 '«Переказати».',
#                                 'Якщо',
#                                 'переказ',
#                                 'з',
#                                 'картки',
#                                 'іншого',
#                                 'банку,',
#                                 'після',
#                                 'натискання',
#                                 'кнопки',
#                                 '«Підтвердити»',
#                                 'необхідно',
#                                 'буде',
#                                 'ще',
#                                 'ввести',
#                                 'пароль',
#                                 '3-D',
#                                 'Secure',
#                                 'за',
#                                 'технологією',
#                                 'Verified',
#                                 'by',
#                                 'Visa',
#                                 'або',
#                                 'Mastercard',
#                                 'SecureCode.',
#                                 'Здійснити',
#                                 'переказ',
#                                 'можна',
#                                 'за',
#                                 'посиланням.',
#                                 'Відеоінструкція']},
#  '_platezhnie-karty_karta-dlia-viplat': {'link': 'https://privatbank.ua/platezhnie-karty/karta-dlia-viplat',
#                                          'name': 'Картка для виплат',
#                                          'sl': ['Як',
#                                                 'заблокувати',
#                                                 'або',
#                                                 'розблокувати',
#                                                 'Картку',
#                                                 'для',
#                                                 'виплат?',
#                                                 'Заблокувати',
#                                                 'або',
#                                                 'розблокувати',
#                                                 'свою',
#                                                 'Картку',
#                                                 'для',
#                                                 'виплат',
#                                                 'Ви',
#                                                 'можете:',
#                                                 'У',
#                                                 'Приват24',
#                                                 '–',
#                                                 'меню',
#                                                 '«Мої',
#                                                 'рахунки»/«Блокування/Розблокування',
#                                                 'карток».',
#                                                 'Через',
#                                                 'мобільний',
#                                                 'додаток',
#                                                 '«SMS-банкінг»',
#                                                 'або',
#                                                 'за',
#                                                 'командою',
#                                                 'SMS-банкингу.',
#                                                 'Зателефонувавши',
#                                                 'в',
#                                                 'клієнтську',
#                                                 'підтримку',
#                                                 '3700',
#                                                 '(з',
#                                                 'мобільних',
#                                                 'телефонів',
#                                                 '–',
#                                                 'безкоштовно).',
#                                                 'Через',
#                                                 'банкомат',
#                                                 'ПриватБанку',
#                                                 'в',
#                                                 'меню',
#                                                 '«Операції',
#                                                 'з',
#                                                 'карткою»/«Додаткові',
#                                                 'послуги»/«Заблокувати/Розблокувати',
#                                                 'картку».',
#                                                 'У',
#                                                 'будь-якому',
#                                                 'відділенні',
#                                                 'ПриватБанку.']},
#  '_platezhnie-karty_universalna': {'link': 'https://privatbank.ua/platezhnie-karty/universalna',
#                                    'name': 'Картка «Універсальна»',
#                                    'sl': ['Показати', 'всi', 'питання', '+34']},
#  '_registracija-telefona-v-banke': {'link': 'https://privatbank.ua/registracija-telefona-v-banke',
#                                     'name': 'Реєстрація телефону в банку',
#                                     'sl': ['Чи',
#                                            'можна',
#                                            'зробити',
#                                            '«фінансовим»',
#                                            'стаціонарний',
#                                            'телефон',
#                                            '(домашній',
#                                            'чи',
#                                            'робочий)?',
#                                            'Ні.',
#                                            '«Фінансовим»',
#                                            'можна',
#                                            'зробити',
#                                            'тільки',
#                                            'мобільний',
#                                            'телефон.']},
#  '_udalenniy-banking_privat24': {'link': 'https://privatbank.ua/udalenniy-banking/privat24',
#                                  'name': 'Інтернет-банк Приват24',
#                                  'sl': ['Спробувати',
#                                         'Приват24',
#                                         'ви',
#                                         'можете:',
#                                         'через',
#                                         'web-версію',
#                                         'за',
#                                         'посиланням',
#                                         'https://next.privat24.ua;',
#                                         'за',
#                                         'допомогою',
#                                         'мобільного',
#                                         'додатка,',
#                                         'доступного',
#                                         'для',
#                                         'завантаження',
#                                         'з',
#                                         'App',
#                                         'Store,',
#                                         'Play',
#                                         'Google',
#                                         'та',
#                                         'App',
#                                         'Gallery.']}}

# %% [markdown]
# ### Завдання 2

# %% [markdown]
# - Ознайомтеся із роботою SQLite та відповідним модулем у Python.
# - Завантажте базу даних `tysql.sqlite` для виконання лабораторної роботи.
# - Підключіться до завантаженої бази SQLite.

# %% [markdown]
# **Зауваження 1.**
# Не обов'язково виконувати всі 15 пунктів. Достатньо 5.
#
# **Зауваження 2.**
# Замість вказаної бази даних можна виконати кілька запитів до бази даних із **Завдання 1**, якщо ви її робили.

# %% [markdown]
# 1. Виведіть інформацію про дану базу.

# %%
import sqlite3
conn = sqlite3.connect('tysql.sqlite')
cursor = conn.cursor()
query = '''CREATE TABLE news (
        NAME TEXT,
        HREF TEXT,
        SLOGAN TEXT
    )'''

cursor.execute('INSERT INTO news VALUES list')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[464], line 10
#       3 cursor = conn.cursor()
#       4 query = '''CREATE TABLE news (
#       5         NAME TEXT,
#       6         HREF TEXT,
#       7         SLOGAN TEXT
#       8     )'''
# ---> 10 cursor.execute('INSERT INTO news VALUES list')
#
# OperationalError: near "list": syntax error

# %% [markdown]
# 2. Виведіть перелік всіх таблиць.

# %%
import sqlite3
conn = sqlite3.connect('tysql.sqlite')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table in tables:
    print(table[0])

# %% [markdown]
# 3. Список всіх cust_id з таблиці Customers table.

# %%
import sqlite3
conn = sqlite3.connect('tysql.sqlite')
cursor = conn.cursor()
cursor.execute('SELECT cust_id FROM Customers')
tables1 = cursor.fetchall()
print(tables1[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[448], line 4
#       2 conn = sqlite3.connect('tysql.sqlite')
#       3 cursor = conn.cursor()
# ----> 4 cursor.execute('SELECT cust_id FROM Customers')
#       5 tables1 = cursor.fetchall()
#       6 зкште(tables1[0])
#
# OperationalError: no such table: Customers

# %% [markdown]
# 4. Всю таблицю Customers table

# %%
cursor.execute('SELECT * FROM Customers')
tables1 = cursor.fetchall()
print(tables1[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[449], line 4
#       2 conn = sqlite3.connect('tysql.sqlite')
#       3 cursor = conn.cursor()
# ----> 4 cursor.execute('SELECT * FROM Customers')
#       5 tables1 = cursor.fetchall()
#       6 print(tables1[0])
#
# OperationalError: no such table: Customers

# %% [markdown]
# 5. Список клієнтів (cust_names) відсортованих від Z до A

# %%
cursor.execute('SELECT * FROM Customers order by cust_names desc')
tables1 = cursor.fetchall()
print(tables1[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[450], line 4
#       2 conn = sqlite3.connect('tysql.sqlite')
#       3 cursor = conn.cursor()
# ----> 4 cursor.execute('SELECT * FROM Customers order by cust_names desc')
#       5 tables1 = cursor.fetchall()
#       6 print(tables1[0])
#
# OperationalError: no such table: Customers

# %% [markdown]
# 6. Таблицю клієнтів та замовлень (cust_id і order_num) . Відсортуйте по клієнту і потім по даті замовлення

# %%
cursor.execute('SELECT * FROM Customers order by cust_id desc, order_num')
tables1 = cursor.fetchall()
print(tables1[0])

# %% [markdown]
# 7. Таблицю (на основі Items) з кількість та вартістю товару. Відсортуйте в порядку спадання по кількості та вартості

# %%
cursor.execute('SELECT Items, count() as "QTY" FROM Customers order by 2 asc')
tables1 = cursor.fetchall()
print(tables1[0])

# %% [markdown]
# 8. Товар (з таблиці Products), ціна якого становить 9.49

# %% [markdown]
# 9. Виведіть назву товару та ціну, яка лежить в діапазоні від  3 до 6. Відсортуйте результат в по ціні в порядку зростання

# %% [markdown]
# 10. Кількість товару, що було продано

# %% [markdown]
# 11. Кількість найменувань товару, ціна якого більша за 4

# %% [markdown]
# 12. Розробіть алгоритм для виведення 3 найдорожчих товарів в базі

# %% [markdown]
# 13. Підрахуйте кількість замовлень для кожного клієнта використовуючи підзапити

# %% [markdown]
# 14. Виведіть список клієнтів та їх замовлення (використайте JOIN)

# %% [markdown]
# 15. Зробіть два запити: список товарів, ціна яких менша 5 та список товарів, ціна який більша рівна 5. Використайте UNION для об'єднання цих запитів
